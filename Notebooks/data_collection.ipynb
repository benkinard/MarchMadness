# %%
import os
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup
from bs4.element import NavigableString
from pathlib import Path

# %%
round_name_to_index = {'First Four': 0, 'First Round (Round of 64)': 1, 'Second Round (Round of 32)': 2,
                       'Sweet 16': 3, 'Elite Eight': 4, 'National semifinals': 5, 'National championship': 6}

# %% [markdown]
# # 2022 Tournament Results

# %%
url = "https://www.ncaa.com/news/basketball-men/article/2022-07-12/2022-ncaa-bracket-mens-march-madness-scores-stats-records"
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
scores_2022 = soup.find("h2", string="2022 NCAA tournament scores").next_sibling.next_sibling

# %%
results_2022 = {'YEAR': [], 'ROUND': [], 'WSEED': [], 'WTEAM': [], 'WSCORE': [], 'LSEED': [], 'LTEAM': [], 'LSCORE': []}
for round_details in scores_2022.children:
    if isinstance(round_details, NavigableString):
        pass
    else:
        round_detail_elements = round_details.children
        
        round_name = next(round_detail_elements).strip()
        
        round_scores_by_location = next(round_detail_elements)
        for location_list_item in round_scores_by_location.children:
            if isinstance(location_list_item, NavigableString):
                pass
            else:
                location_list_sub_items = location_list_item.children
                round_location = next(location_list_sub_items).strip()
                if round_location in ['National semifinals', 'National championship']:
                    round_name = round_location
                
                location_scores = next(location_list_sub_items)
                for matchup in location_scores.children:
                    if isinstance(matchup, NavigableString):
                        pass
                    else:
                        matchup_text = matchup.text
                        
                        ### Parse Winning Team Info ###
                        
                        # Parse the seed of the first team listed
                        match = re.search(r'(?<=No. )\d{1,2}', matchup_text)
                        winning_seed = match[0]
                        matchup_text = matchup_text[match.end()+1:]
                        
                        # Parse the name of the first team listed
                        match = re.search(r'^\D+(?=\s\d{2,3})', matchup_text)
                        winning_team = match[0]
                        matchup_text = matchup_text[match.end()+1:]
                        
                        # Parse the score of the first team listed
                        match = re.search(r'^\d{2,3}(?=,\s)', matchup_text)
                        winning_score = match[0]
                        matchup_text = matchup_text[match.end()+2:]
                        
                        ### Parse Losing Team Info ###
                        
                        # Parse the seed of the second team listed
                        match = re.search(r'((?<=No. )\d{1,2})|(^\d{1,2})', matchup_text)
                        losing_seed = match[0]
                        matchup_text = matchup_text[match.end()+1:]
                        
                        # Parse the name of the second team listed
                        match = re.search(r'^\D+(?=\s\d{2,3})', matchup_text)
                        losing_team = match[0]
                        matchup_text = matchup_text[match.end()+1:]
                        
                        # Parse the score of the second team listed
                        match = re.search(r'^\d{2,3}', matchup_text)
                        losing_score = match[0]
                        
                        results_2022['YEAR'].append(2022)
                        results_2022['ROUND'].append(round_name_to_index[round_name])
                        results_2022['WSEED'].append(int(winning_seed))
                        results_2022['WTEAM'].append(winning_team)
                        results_2022['WSCORE'].append(int(winning_score))
                        results_2022['LSEED'].append(int(losing_seed))
                        results_2022['LTEAM'].append(losing_team)
                        results_2022['LSCORE'].append(int(losing_score))

# %%
results_2022 = pd.DataFrame(results_2022)
results_2022
# Out:
#     YEAR  ROUND  WSEED           WTEAM  WSCORE  LSEED           LTEAM  LSCORE
# 0   2022      0     12         Indiana      66     12         Wyoming      58
# 1   2022      0     16    Wright State      93     16          Bryant      82
# 2   2022      0     11      Notre Dame      89     11         Rutgers      87
# 3   2022      0     16  Texas Southern      76     16     Tex. A&M CC      67
# 4   2022      1      1          Kansas      83     16  Texas Southern      56
# ..   ...    ...    ...             ...     ...    ...             ...     ...
# 62  2022      4      8  North Carolina      69     15     St. Peter’s      49
# 63  2022      4      2       Villanova      50      5         Houston      44
# 64  2022      5      8     N. Carolina      81      2            Duke      77
# 65  2022      5      1          Kansas      81      2       Villanova      65
# 66  2022      6      1          Kansas      72      8     N. Carolina      69
#
# [67 rows x 8 columns]

# %% [markdown]
# # 2023 Tournament Results

# %%
url = 'https://www.ncaa.com/news/basketball-men/article/2023-04-18/2023-ncaa-bracket-scores-stats-march-madness-mens-tournament'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
scores_2023 = soup.find("h3", string="2023 NCAA tournament scores").next_sibling.next_sibling

# %%
results_2023 = {'YEAR': [], 'ROUND': [], 'WSEED': [], 'WTEAM': [], 'WSCORE': [], 'LSEED': [], 'LTEAM': [], 'LSCORE': []}
for round_details in scores_2023.children:
    if isinstance(round_details, NavigableString):
        pass
    else:
        round_detail_elements = round_details.children
        
        round_name = next(round_detail_elements).strip()
        
        round_scores_by_location = next(round_detail_elements)
        for location_list_item in round_scores_by_location.children:
            if isinstance(location_list_item, NavigableString):
                pass
            else:
                location_list_sub_items = location_list_item.children
                round_location = next(location_list_sub_items).strip()
                if round_location == 'National semifinals':
                    round_name = round_location
                
                if round_name == 'National championship':
                    matchup_text = round_location

                    ### Parse Winning Team Info ###

                    # Parse the seed of the first team listed
                    match = re.search(r'(?<=No. )\d{1,2}', matchup_text)
                    winning_seed = match[0]
                    matchup_text = matchup_text[match.end()+1:]

                    # Parse the name of the first team listed
                    match = re.search(r'^\D+(?=\s\d{2,3})', matchup_text)
                    winning_team = match[0]
                    matchup_text = matchup_text[match.end()+1:]

                    # Parse the score of the first team listed
                    match = re.search(r'^\d{2,3}(?=,\s)', matchup_text)
                    winning_score = match[0]
                    matchup_text = matchup_text[match.end()+2:]

                    ### Parse Losing Team Info ###

                    # Parse the seed of the second team listed
                    match = re.search(r'((?<=No. )\d{1,2})|(^\d{1,2})', matchup_text)
                    losing_seed = match[0]
                    matchup_text = matchup_text[match.end()+1:]

                    # Parse the name of the second team listed
                    match = re.search(r'(^\D+(?=\s\d{2,3}))|(^\D+(?=\s\(\d{2,3}\)))', matchup_text)
                    losing_team = match[0]
                    matchup_text = matchup_text[match.end()+1:]

                    # Parse the score of the second team listed
                    match = re.search(r'(^\d{2,3})|(?<=\()\d{2,3}(?=\))', matchup_text)
                    losing_score = match[0]
                    
                    results_2023['YEAR'].append(2023)
                    results_2023['ROUND'].append(round_name_to_index[round_name])
                    results_2023['WSEED'].append(int(winning_seed))
                    results_2023['WTEAM'].append(winning_team)
                    results_2023['WSCORE'].append(int(winning_score))
                    results_2023['LSEED'].append(int(losing_seed))
                    results_2023['LTEAM'].append(losing_team)
                    results_2023['LSCORE'].append(int(losing_score))
                else:
                    location_scores = next(location_list_sub_items)
                    for matchup in location_scores.children:
                        if isinstance(matchup, NavigableString):
                            pass
                        else:
                            matchup_text = matchup.text

                            ### Parse Winning Team Info ###

                            # Parse the seed of the first team listed
                            match = re.search(r'(?<=No. )\d{1,2}', matchup_text)
                            winning_seed = match[0]
                            matchup_text = matchup_text[match.end()+1:]

                            # Parse the name of the first team listed
                            match = re.search(r'^\D+(?=\s\d{2,3})', matchup_text)
                            winning_team = match[0]
                            matchup_text = matchup_text[match.end()+1:]

                            # Parse the score of the first team listed
                            match = re.search(r'^\d{2,3}(?=,\s)', matchup_text)
                            winning_score = match[0]
                            matchup_text = matchup_text[match.end()+2:]

                            ### Parse Losing Team Info ###

                            # Parse the seed of the second team listed
                            match = re.search(r'((?<=No. )\d{1,2})|(^\d{1,2})', matchup_text)
                            losing_seed = match[0]
                            matchup_text = matchup_text[match.end()+1:]

                            # Parse the name of the second team listed
                            match = re.search(r'(^\D+(?=\s\d{2,3}))|(^\D+(?=\s\(\d{2,3}\)))', matchup_text)
                            losing_team = match[0]
                            matchup_text = matchup_text[match.end()+1:]

                            # Parse the score of the second team listed
                            match = re.search(r'(^\d{2,3})|(?<=\()\d{2,3}(?=\))', matchup_text)
                            losing_score = match[0]
                            
                            results_2023['YEAR'].append(2023)
                            results_2023['ROUND'].append(round_name_to_index[round_name])
                            results_2023['WSEED'].append(int(winning_seed))
                            results_2023['WTEAM'].append(winning_team)
                            results_2023['WSCORE'].append(int(winning_score))
                            results_2023['LSEED'].append(int(losing_seed))
                            results_2023['LTEAM'].append(losing_team)
                            results_2023['LSCORE'].append(int(losing_score))

# %%
results_2023 = pd.DataFrame(results_2023)
results_2023
# Out:
#     YEAR  ROUND  WSEED           WTEAM  WSCORE  LSEED            LTEAM  LSCORE
# 0   2023      0     16             FDU      84     16   Texas Southern      61
# 1   2023      0     11     Arizona St.      98     11           Nevada      73
# 2   2023      0     16  Texas A&M - CC      75     16  SE Missouri St.      71
# 3   2023      0     11      Pittsburgh      60     11  Mississippi St.      59
# 4   2023      1      1         Houston      63     16   North Kentucky      52
# ..   ...    ...    ...             ...     ...    ...              ...     ...
# 62  2023      4      9             FAU      79      3       Kansas St.      76
# 63  2023      4      5   San Diego St.      57      6        Creighton      56
# 64  2023      5      5   San Diego St.      72      9              FAU      71
# 65  2023      5      4           UConn      72      5       Miami (FL)      59
# 66  2023      6      4           UConn      76      5    San Diego St.      59
#
# [67 rows x 8 columns]

# %% [markdown]
# # Write Combined Results to CSV

# %%
results_2022_2023 = pd.concat([results_2022, results_2023], ignore_index=True)
results_2022_2023.iloc[::-1]
# Out:
#      YEAR  ROUND  WSEED           WTEAM  WSCORE  LSEED           LTEAM  LSCORE
# 133  2023      6      4           UConn      76      5   San Diego St.      59
# 132  2023      5      4           UConn      72      5      Miami (FL)      59
# 131  2023      5      5   San Diego St.      72      9             FAU      71
# 130  2023      4      5   San Diego St.      57      6       Creighton      56
# 129  2023      4      9             FAU      79      3      Kansas St.      76
# ..    ...    ...    ...             ...     ...    ...             ...     ...
# 4    2022      1      1          Kansas      83     16  Texas Southern      56
# 3    2022      0     16  Texas Southern      76     16     Tex. A&M CC      67
# 2    2022      0     11      Notre Dame      89     11         Rutgers      87
# 1    2022      0     16    Wright State      93     16          Bryant      82
# 0    2022      0     12         Indiana      66     12         Wyoming      58
#
# [134 rows x 8 columns]

# %%
PROJ_PATH = Path(os.getcwd()).parent
DATA_PATH = PROJ_PATH / 'Data'

# %%
results_2022_2023.to_csv(DATA_PATH / 'Tournament_Game_Results_22_23.csv', index=False)

# %% [markdown]
# # 2024 Tournament Results

# %%
url = 'https://www.ncaa.com/news/basketball-men/article/2024-12-06/2024-ncaa-bracket-scores-stats-march-madness-mens-tournament'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
scores_2024 = soup.find("h3", string="2024 NCAA tournament scores").next_sibling.next_sibling

# %%
results_2024 = {'YEAR': [], 'ROUND': [], 'WSEED': [], 'WTEAM': [], 'WSCORE': [], 'LSEED': [], 'LTEAM': [], 'LSCORE': []}
for round_details in scores_2024.children:
    if isinstance(round_details, NavigableString):
        pass
    else:
        round_detail_elements = round_details.children
        
        round_name = next(round_detail_elements).strip()
        
        round_scores_by_location = next(round_detail_elements)
        for location_list_item in round_scores_by_location.children:
            if isinstance(location_list_item, NavigableString):
                pass
            else:
                location_list_sub_items = location_list_item.children
                round_location = next(location_list_sub_items).strip()
                if round_location == 'National semifinals':
                    round_name = round_location
                
                if round_name == 'National championship':
                    matchup_text = round_location

                    ### Parse Winning Team Info ###

                    # Parse the seed of the first team listed
                    match = re.search(r'(?<=No. )\d{1,2}', matchup_text)
                    winning_seed = match[0]
                    matchup_text = matchup_text[match.end()+1:]

                    # Parse the name of the first team listed
                    match = re.search(r'^\D+(?=\s\d{2,3})', matchup_text)
                    winning_team = match[0]
                    matchup_text = matchup_text[match.end()+1:]

                    # Parse the score of the first team listed
                    match = re.search(r'^\d{2,3}(?=,\s)', matchup_text)
                    winning_score = match[0]
                    matchup_text = matchup_text[match.end()+2:]

                    ### Parse Losing Team Info ###

                    # Parse the seed of the second team listed
                    match = re.search(r'((?<=No. )\d{1,2})|(^\d{1,2})', matchup_text)
                    losing_seed = match[0]
                    matchup_text = matchup_text[match.end()+1:]

                    # Parse the name of the second team listed
                    match = re.search(r'(^\D+(?=\s\d{2,3}))|(^\D+(?=\s\(\d{2,3}\)))', matchup_text)
                    losing_team = match[0]
                    matchup_text = matchup_text[match.end()+1:]

                    # Parse the score of the second team listed
                    match = re.search(r'(^\d{2,3})|(?<=\()\d{2,3}(?=\))', matchup_text)
                    losing_score = match[0]
                    
                    results_2024['YEAR'].append(2024)
                    results_2024['ROUND'].append(round_name_to_index[round_name])
                    results_2024['WSEED'].append(int(winning_seed))
                    results_2024['WTEAM'].append(winning_team)
                    results_2024['WSCORE'].append(int(winning_score))
                    results_2024['LSEED'].append(int(losing_seed))
                    results_2024['LTEAM'].append(losing_team)
                    results_2024['LSCORE'].append(int(losing_score))
                else:
                    location_scores = next(location_list_sub_items)
                    for matchup in location_scores.children:
                        if isinstance(matchup, NavigableString):
                            pass
                        else:
                            matchup_text = matchup.text

                            ### Parse Winning Team Info ###

                            # Parse the seed of the first team listed
                            match = re.search(r'(?<=No. )\d{1,2}', matchup_text)
                            winning_seed = match[0]
                            matchup_text = matchup_text[match.end()+1:]

                            # Parse the name of the first team listed
                            match = re.search(r'^\D+(?=\s\d{2,3})', matchup_text)
                            winning_team = match[0]
                            matchup_text = matchup_text[match.end()+1:]

                            # Parse the score of the first team listed
                            match = re.search(r'^\d{2,3}(?=,\s)', matchup_text)
                            winning_score = match[0]
                            matchup_text = matchup_text[match.end()+2:]

                            ### Parse Losing Team Info ###

                            # Parse the seed of the second team listed
                            match = re.search(r'((?<=No. )\d{1,2})|(^\d{1,2})', matchup_text)
                            losing_seed = match[0]
                            matchup_text = matchup_text[match.end()+1:]

                            # Parse the name of the second team listed
                            match = re.search(r'(^\D+(?=\s\d{2,3}))|(^\D+(?=\s\(\d{2,3}\)))', matchup_text)
                            losing_team = match[0]
                            matchup_text = matchup_text[match.end()+1:]

                            # Parse the score of the second team listed
                            match = re.search(r'(^\d{2,3})|(?<=\()\d{2,3}(?=\))', matchup_text)
                            losing_score = match[0]
                            
                            results_2024['YEAR'].append(2024)
                            results_2024['ROUND'].append(round_name_to_index[round_name])
                            results_2024['WSEED'].append(int(winning_seed))
                            results_2024['WTEAM'].append(winning_team)
                            results_2024['WSCORE'].append(int(winning_score))
                            results_2024['LSEED'].append(int(losing_seed))
                            results_2024['LTEAM'].append(losing_team)
                            results_2024['LSCORE'].append(int(losing_score))

# %%
results_2024 = pd.DataFrame(results_2024)
results_2024
# Out:
#     YEAR  ROUND  WSEED            WTEAM  WSCORE  LSEED          LTEAM  LSCORE
# 0   2024      0     16           Wagner      71     16         Howard      68
# 1   2024      0     10   Colorado State      67     10       Virginia      42
# 2   2024      0     16  Grambling State      88     16  Montana State      81
# 3   2024      0     10         Colorado      60     10    Boise State      53
# 4   2024      1      1            UConn      91     16        Stetson      52
# ..   ...    ...    ...              ...     ...    ...            ...     ...
# 62  2024      4     11         NC State      76      4           Duke      64
# 63  2024      4      1           Purdue      72      2      Tennessee      66
# 64  2024      5      1            UConn      86      4        Alabama      72
# 65  2024      5      1           Purdue      63     11       NC State      50
# 66  2024      5      1            UConn      75      1         Purdue      60
#
# [67 rows x 8 columns]

# %%
results_2024.iloc[::-1]
# Out:
#     YEAR  ROUND  WSEED            WTEAM  WSCORE  LSEED          LTEAM  LSCORE
# 66  2024      5      1            UConn      75      1         Purdue      60
# 65  2024      5      1           Purdue      63     11       NC State      50
# 64  2024      5      1            UConn      86      4        Alabama      72
# 63  2024      4      1           Purdue      72      2      Tennessee      66
# 62  2024      4     11         NC State      76      4           Duke      64
# ..   ...    ...    ...              ...     ...    ...            ...     ...
# 4   2024      1      1            UConn      91     16        Stetson      52
# 3   2024      0     10         Colorado      60     10    Boise State      53
# 2   2024      0     16  Grambling State      88     16  Montana State      81
# 1   2024      0     10   Colorado State      67     10       Virginia      42
# 0   2024      0     16           Wagner      71     16         Howard      68
#
# [67 rows x 8 columns]

# %%
PROJ_PATH = Path(os.getcwd()).parent
DATA_PATH = PROJ_PATH / 'Data'

# %%
results_2024.iloc[::-1].to_csv(DATA_PATH / 'Tournament_Game_Results_24.csv', index=False)

# %% [markdown]
# # 2025 Tournament Results

# %%
url = 'https://www.ncaa.com/news/basketball-men/article/2025-06-12/2026-march-madness-mens-ncaa-tournament-schedule-dates'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
round_name_to_index = {'First Four': 0, 'First Round': 1, 'Second Round': 2,
                       'Sweet 16': 3, 'Elite Eight': 4, 'Final Four': 5, 'National championship': 6}

results_2025 = {'YEAR': [], 'ROUND': [], 'WSEED': [], 'WTEAM': [], 'WSCORE': [], 'LSEED': [], 'LTEAM': [], 'LSCORE': []}
round_scores = soup.find("h3", string="2025 NCAA tournament schedule, scores, highlights").next_sibling.next_sibling
round_title = ''

while "National championship" not in str(round_title):
    round_title = round_scores.next_sibling.next_sibling
    
    # Parse title
    match = re.search(r'(?<=\d\s\()\w+\s\w+(?=\s|\)|/)', next(round_title.children).text)
    round_name = match[0]
    print(round_name)
    
    round_scores = round_title.next_sibling.next_sibling
    for round_details in round_scores.children:
        if isinstance(round_details, NavigableString):
            pass
        else:
            matchup_text = next(round_details.children).text
            print(matchup_text)
            
            ### Parse Winning Team Info ###

            # Parse the seed of the first team listed
            match = re.search(r'(?<=\()\d{1,2}(?=\))', matchup_text)
            winning_seed = match[0]
            matchup_text = matchup_text[match.end()+2:]

            # Parse the name of the first team listed
            match = re.search(r'^\D+(?=\s\d{2,3})', matchup_text)
            winning_team = match[0]
            matchup_text = matchup_text[match.end()+1:]

            # Parse the score of the first team listed
            match = re.search(r'^\d{2,3}(?=,\s)', matchup_text)
            winning_score = match[0]
            matchup_text = matchup_text[match.end()+2:]

            ### Parse Losing Team Info ###

            # Parse the seed of the second team listed
            match = re.search(r'(?<=\()\d{1,2}(?=\))', matchup_text)
            losing_seed = match[0]
            matchup_text = matchup_text[match.end()+2:]

            # Parse the name of the second team listed
            match = re.search(r'^\D+(?=\s\d{2,3})', matchup_text)
            losing_team = match[0]
            matchup_text = matchup_text[match.end()+1:]

            # Parse the score of the second team listed
            match = re.search(r'^\d{2,3}', matchup_text)
            losing_score = match[0]

            results_2025['YEAR'].append(2025)
            results_2025['ROUND'].append(round_name_to_index[round_name])
            results_2025['WSEED'].append(int(winning_seed))
            results_2025['WTEAM'].append(winning_team)
            results_2025['WSCORE'].append(int(winning_score))
            results_2025['LSEED'].append(int(losing_seed))
            results_2025['LTEAM'].append(losing_team)
            results_2025['LSCORE'].append(int(losing_score))
    
    print("\n")
# Out:
# First Four
# (16) Alabama State 70, (16) Saint Francis 68
# (11) North Carolina 95, (11) San Diego State 68
#
#
# First Four
# (16) Mount St. Mary's 83, (16) American University 72
# (11) Xavier 86, (11) Texas 80
#
#
# First Round
# (9) Creighton 89, (8) Louisville 75
# (4) Purdue 75, (13) High Point 63
# (3) Wisconsin 85, (14) Montana 66
# (1) Houston 78, (16) SIU Edwardsville 40
# (1) Auburn 83, (16) Alabama State 63
# (12) McNeese 69, (5) Clemson 67
# (6) BYU 80, (11) VCU 71
# (8) Gonzaga 89, (9) Georgia 68
# (2) Tennessee 77, (15) Wofford 62
# (10) Arkansas 79, (7) Kansas 72
# (4) Texas A&M 80, (13) Yale 71
# (11) Drake 67, (6) Missouri 57
# (7) UCLA 72, (10) Utah State 47
# (2) St. John's 83, (15) Omaha 53
# (5) Michigan 68, (12) UC San Diego 65
# (3) Texas Tech 82, (14) UNC Wilmington 72
#
#
# First Round
# (9) Baylor 75, (8) Mississippi State 72
# (2) Alabama 90, (15) Robert Morris 81
# (3) Iowa State 82, (14) Lipscomb 55
# (12) Colorado State 78, (5) Memphis 70
# (1) Duke 93, (16) Mount St. Mary's 49
# (7) Saint Mary's 59, (10) Vanderbilt 56
# (6) Ole Miss 71, (11) North Carolina 64
# (4) Maryland 81, (13) Grand Canyon 49
# (1) Florida 95, (16) Norfolk State 69
# (3) Kentucky 76, (14) Troy 57
# (10) New Mexico 75, (7) Marquette 66
# (4) Arizona 93, (13) Akron 65
# (8) UConn 67, (9) Oklahoma 59
# (6) Illinois 86, (11) Xavier 73
# (2) Michigan State 87, (15) Bryant 62
# (5) Oregon 81, (12) Liberty 52
#
#
# Second Round
# (4) Purdue 76, (12) McNeese 62
# (10) Arkansas 75, (2) St. John's 66
# (5) Michigan 91, (4) Texas A&M 79
# (3) Texas Tech 77, (11) Drake 64
# (1) Auburn 82, (9) Creighton 70
# (6) BYU 91, (3) Wisconsin 89
# (1) Houston 81, (8) Gonzaga 76
# (2) Tennessee 67, (7) UCLA 58
#
#
# Second Round
# (1) Florida 77, (8) UConn 75
# (1) Duke 89, (9) Baylor 66
# (3) Kentucky 84, (6) Illinois 75
# (2) Alabama 80, (7) Saint Mary's 66
# (4) Maryland 72, (12) Colorado State 71
# (6) Ole Miss 91, (3) Iowa State 78
# (2) Michigan State 71, (10) New Mexico 63
# (4) Arizona 87, (5) Oregon 83
#
#
# Sweet 16
# (2) Alabama 113, (6) BYU 88
# (1) Florida 87, (4) Maryland 71
# (1) Duke 100, (4) Arizona 93
# (3) Texas Tech 85, (10) Arkansas 83 (OT)
#
#
# Sweet 16
# (2) Michigan State 73, (6) Ole Miss 70
# (2) Tennessee 78, (3) Kentucky 65
# (1) Auburn 78, (5) Michigan 65
# (1) Houston 62, (4) Purdue 60
#
#
# Elite Eight
# (1) Florida 84, (3) Texas Tech 79
# (1) Duke 85, (2) Alabama 65
#
#
# Elite Eight
# (1) Houston 69, (2) Tennessee 50
# (1) Auburn 70, (2) Michigan State 64
#
#
# Final Four
# (1) Florida 79, (1) Auburn 73
# (1) Houston 70, (1) Duke 67
#
#
# National championship
# (1) Florida 65, (1) Houston 63

# %%
results_2025 = pd.DataFrame(results_2025)
results_2025
# Out:
#     YEAR  ROUND  WSEED             WTEAM  WSCORE  LSEED                LTEAM  \
# 0   2025      0     16     Alabama State      70     16        Saint Francis
# 1   2025      0     11    North Carolina      95     11      San Diego State
# 2   2025      0     16  Mount St. Mary's      83     16  American University
# 3   2025      0     11            Xavier      86     11                Texas
# 4   2025      1      9         Creighton      89      8           Louisville
# ..   ...    ...    ...               ...     ...    ...                  ...
# 62  2025      4      1           Houston      69      2            Tennessee
# 63  2025      4      1            Auburn      70      2       Michigan State
# 64  2025      5      1           Florida      79      1               Auburn
# 65  2025      5      1           Houston      70      1                 Duke
# 66  2025      6      1           Florida      65      1              Houston
#
#     LSCORE
# 0       68
# 1       68
# 2       72
# 3       80
# 4       75
# ..     ...
# 62      50
# 63      64
# 64      73
# 65      67
# 66      63
#
# [67 rows x 8 columns]

# %%
results_2025.iloc[::-1]
# Out:
#     YEAR  ROUND  WSEED             WTEAM  WSCORE  LSEED                LTEAM  \
# 66  2025      6      1           Florida      65      1              Houston
# 65  2025      5      1           Houston      70      1                 Duke
# 64  2025      5      1           Florida      79      1               Auburn
# 63  2025      4      1            Auburn      70      2       Michigan State
# 62  2025      4      1           Houston      69      2            Tennessee
# ..   ...    ...    ...               ...     ...    ...                  ...
# 4   2025      1      9         Creighton      89      8           Louisville
# 3   2025      0     11            Xavier      86     11                Texas
# 2   2025      0     16  Mount St. Mary's      83     16  American University
# 1   2025      0     11    North Carolina      95     11      San Diego State
# 0   2025      0     16     Alabama State      70     16        Saint Francis
#
#     LSCORE
# 66      63
# 65      67
# 64      73
# 63      64
# 62      50
# ..     ...
# 4       75
# 3       80
# 2       72
# 1       68
# 0       68
#
# [67 rows x 8 columns]

# %%
PROJ_PATH = Path(os.getcwd()).parent
DATA_PATH = PROJ_PATH / 'Data'

# %%
results_2025.iloc[::-1].to_csv(DATA_PATH / 'Tournament_Game_Results_25.csv', index=False)
