# %%
import os
import pandas as pd
from pathlib import Path

# %%
PROJ_PATH = Path(os.getcwd()).parent
DATA_PATH = PROJ_PATH / 'Data'

# %%
team_stats = pd.read_csv(DATA_PATH / 'Tournament_Team_Data.csv')
game_results = pd.read_csv(DATA_PATH / 'Tournament_Game_Results.csv')

# %%
team_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011 entries, 0 to 1010
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   YEAR                            1011 non-null   int64
#  1   SEED                            1011 non-null   int64
#  2   TEAM                            1011 non-null   object
#  3   ROUND                           1011 non-null   int64
#  4   KENPOM ADJUSTED EFFICIENCY      1011 non-null   float64
#  5   KENPOM ADJUSTED OFFENSE         1011 non-null   float64
#  6   KENPOM ADJUSTED DEFENSE         1011 non-null   float64
#  7   KENPOM ADJUSTED TEMPO           1011 non-null   float64
#  8   BARTTORVIK ADJUSTED EFFICIENCY  1011 non-null   float64
#  9   BARTTORVIK ADJUSTED OFFENSE     1011 non-null   float64
#  10  BARTTORVIK ADJUSTED DEFENSE     1011 non-null   float64
#  11  BARTHAG                         1011 non-null   float64
#  12  ELITE SOS                       1011 non-null   float64
#  13  BARTTORVIK ADJUSTED TEMPO       1011 non-null   float64
#  14  2PT %                           1011 non-null   float64
#  15  3PT %                           1011 non-null   float64
#  16  FREE THROW %                    1011 non-null   float64
#  17  EFG %                           1011 non-null   float64
#  18  FREE THROW RATE                 1011 non-null   float64
#  19  3PT RATE                        1011 non-null   float64
#  20  ASSIST %                        1011 non-null   float64
#  21  OFFENSIVE REBOUND %             1011 non-null   float64
#  22  DEFENSIVE REBOUND %             1011 non-null   float64
#  23  BLOCK %                         1011 non-null   float64
#  24  TURNOVER %                      1011 non-null   float64
#  25  2PT % DEFENSE                   1011 non-null   float64
#  26  3PT % DEFENSE                   1011 non-null   float64
#  27  FREE THROW % DEFENSE            1011 non-null   float64
#  28  EFG % DEFENSE                   1011 non-null   float64
#  29  FREE THROW RATE DEFENSE         1011 non-null   float64
#  30  3PT RATE DEFENSE                1011 non-null   float64
#  31  OP ASSIST %                     1011 non-null   float64
#  32  OP O REB %                      1011 non-null   float64
#  33  OP D REB %                      1011 non-null   float64
#  34  BLOCKED %                       1011 non-null   float64
#  35  TURNOVER % DEFENSE              1011 non-null   float64
#  36  WINS ABOVE BUBBLE               1011 non-null   float64
#  37  WIN %                           1011 non-null   float64
#  38  POINTS PER POSSESSION OFFENSE   1011 non-null   float64
#  39  POINTS PER POSSESSION DEFENSE   1011 non-null   float64
#  40  TEAM.1                          1011 non-null   object
# dtypes: float64(36), int64(3), object(2)
# memory usage: 324.0+ KB

# %%
# Select columns from team_stats
team_stats
# Out:
#       YEAR  SEED                    TEAM  ROUND  KENPOM ADJUSTED EFFICIENCY  \
# 0     2023     1                 Alabama      0                     26.9363
# 1     2023     1                 Houston      0                     29.8743
# 2     2023     1                  Kansas      0                     23.1345
# 3     2023     1                  Purdue      0                     24.7732
# 4     2023     2                 Arizona      0                     22.8757
# ...    ...   ...                     ...    ...                         ...
# 1006  2008    16  Mississippi Valley St.     64                    -15.0000
# 1007  2008    16        Mount St. Mary's     64                     -1.0000
# 1008  2008    16            Portland St.     64                      5.8000
# 1009  2008    16            UT Arlington     64                     -2.0000
# 1010  2008    16              Coppin St.     68                    -14.2000
#
#       KENPOM ADJUSTED OFFENSE  KENPOM ADJUSTED DEFENSE  KENPOM ADJUSTED TEMPO  \
# 0                     115.832                  88.8960                72.7700
# 1                     118.854                  88.9798                63.3827
# 2                     114.703                  91.5684                69.2256
# 3                     119.951                  95.1774                64.2174
# 4                     120.078                  97.2023                72.2672
# ...                       ...                      ...                    ...
# 1006                   92.100                 107.1000                62.4000
# 1007                   99.000                 100.1000                65.2000
# 1008                  108.400                 102.6000                65.8000
# 1009                  101.100                 103.1000                68.0000
# 1010                   92.400                 106.7000                62.2000
#
#       BARTTORVIK ADJUSTED EFFICIENCY  BARTTORVIK ADJUSTED OFFENSE  ...  \
# 0                             27.588                      116.981  ...
# 1                             28.290                      118.260  ...
# 2                             21.359                      113.750  ...
# 3                             25.247                      119.495  ...
# 4                             23.914                      120.450  ...
# ...                              ...                          ...  ...
# 1006                         -15.300                       90.000  ...
# 1007                          -1.800                       97.300  ...
# 1008                           3.500                      105.300  ...
# 1009                          -2.100                       99.100  ...
# 1010                         -15.400                       90.200  ...
#
#       OP ASSIST %  OP O REB %  OP D REB %  BLOCKED %  TURNOVER % DEFENSE  \
# 0            41.8        27.6        66.2       11.4                16.0
# 1            53.6        27.4        62.9        6.6                22.0
# 2            46.2        28.3        71.6        7.3                20.2
# 3            51.5        23.3        61.7        8.6                15.4
# 4            49.4        26.2        68.9        9.3                16.9
# ...           ...         ...         ...        ...                 ...
# 1006         50.4        34.5        67.5        9.1                22.9
# 1007         47.8        33.0        70.0        7.5                22.0
# 1008         54.8        31.3        66.0        6.3                21.5
# 1009         56.0        30.5        68.2        7.6                20.8
# 1010         60.5        38.5        68.0       11.3                25.2
#
#       WINS ABOVE BUBBLE      WIN %  POINTS PER POSSESSION OFFENSE  \
# 0                  10.6  85.294118                          1.106
# 1                   8.4  91.176471                          1.158
# 2                  10.5  79.411765                          1.062
# 3                   9.2  85.294118                          1.135
# 4                   7.5  82.352941                          1.134
# ...                 ...        ...                            ...
# 1006              -10.0  50.000000                          0.927
# 1007               -9.5  56.250000                          1.006
# 1008               -3.4  70.000000                          1.088
# 1009               -7.0  60.710000                          1.006
# 1010              -13.0  41.180000                          0.907
#
#       POINTS PER POSSESSION DEFENSE                  TEAM.1
# 0                             0.922                 Alabama
# 1                             0.872                 Houston
# 2                             0.963                  Kansas
# 3                             0.974                  Purdue
# 4                             0.981                 Arizona
# ...                             ...                     ...
# 1006                          0.997  Mississippi Valley St.
# 1007                          0.968        Mount St. Mary's
# 1008                          1.003            Portland St.
# 1009                          0.971            UT Arlington
# 1010                          1.013              Coppin St.
#
# [1011 rows x 41 columns]

# %%
game_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2317 entries, 0 to 2316
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   YEAR         2317 non-null   int64
#  1   ROUND        2317 non-null   int64
#  2   WSEED        2317 non-null   int64
#  3   WTEAM        2317 non-null   object
#  4   WSCORE       2317 non-null   int64
#  5   LSEED        2317 non-null   int64
#  6   LTEAM        2317 non-null   object
#  7   LSCORE       2317 non-null   int64
#  8   BETTER_SEED  2317 non-null   int64
#  9   BETTER_TEAM  2317 non-null   object
#  10  WORSE_SEED   2317 non-null   int64
#  11  WORSE_TEAM   2317 non-null   object
#  12  UPSET        2317 non-null   int64
# dtypes: int64(9), object(4)
# memory usage: 235.4+ KB

# %%
game_results
# Out:
#       YEAR  ROUND  WSEED                 WTEAM  WSCORE  LSEED  \
# 0     2021      6      1                Baylor      86      1
# 1     2021      5      1               Gonzaga      93     11
# 2     2021      5      1                Baylor      78      2
# 3     2021      4      2               Houston      67     12
# 4     2021      4      1                Baylor      81      3
# ...    ...    ...    ...                   ...     ...    ...
# 2312  1985      1      3  North Carolina State      65     14
# 2313  1985      1      4            Ohio State      75     13
# 2314  1985      1      1              Oklahoma      96     16
# 2315  1985      1      7            Notre Dame      79     10
# 2316  1985      1      2        North Carolina      76     15
#
#                        LTEAM  LSCORE
# 0                    Gonzaga      70
# 1                       UCLA      90
# 2                    Houston      59
# 3               Oregon State      61
# 4                   Arkansas      72
# ...                      ...     ...
# 2312                  Nevada      56
# 2313              Iowa State      64
# 2314      North Carolina A&T      83
# 2315            Oregon State      70
# 2316  Middle Tennessee State      57
#
# [2317 rows x 8 columns]

# %%
better_seeds = []
better_teams = []
worse_seeds = []
worse_teams = []
upsets = []

for row in game_results.iterrows():
    row = row[1]
    if row['WSEED'] == row['LSEED']:  # Maybe consider team from region with better #1 seed to be better seed
        print("Do something")
        better_seeds.append(row['WSEED'])
        better_teams.append(row['WTEAM'])
        worse_seeds.append(row['LSEED'])
        worse_teams.append(row['LTEAM'])
        upsets.append(0)
    elif row['WSEED'] < row['LSEED']:
        better_seeds.append(row['WSEED'])
        better_teams.append(row['WTEAM'])
        worse_seeds.append(row['LSEED'])
        worse_teams.append(row['LTEAM'])
        upsets.append(0)
    else:
        better_seeds.append(row['LSEED'])
        better_teams.append(row['LTEAM'])
        worse_seeds.append(row['WSEED'])
        worse_teams.append(row['WTEAM'])
        upsets.append(1)

game_results['BETTER_SEED'] = better_seeds
game_results['BETTER_TEAM'] = better_teams
game_results['WORSE_SEED'] = worse_seeds
game_results['WORSE_TEAM'] = worse_teams
game_results['UPSET'] = upsets
# Out:
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something
# Do something

# %%
game_results[['YEAR', 'ROUND', 'BETTER_SEED', 'BETTER_TEAM', 'WORSE_SEED', 'WORSE_TEAM', 'UPSET']]
# Out:
#       YEAR  ROUND  BETTER_SEED           BETTER_TEAM  WORSE_SEED  \
# 0     2021      6            1                Baylor           1
# 1     2021      5            1               Gonzaga          11
# 2     2021      5            1                Baylor           2
# 3     2021      4            2               Houston          12
# 4     2021      4            1                Baylor           3
# ...    ...    ...          ...                   ...         ...
# 2312  1985      1            3  North Carolina State          14
# 2313  1985      1            4            Ohio State          13
# 2314  1985      1            1              Oklahoma          16
# 2315  1985      1            7            Notre Dame          10
# 2316  1985      1            2        North Carolina          15
#
#                   WORSE_TEAM  UPSET
# 0                    Gonzaga      0
# 1                       UCLA      0
# 2                    Houston      0
# 3               Oregon State      0
# 4                   Arkansas      0
# ...                      ...    ...
# 2312                  Nevada      0
# 2313              Iowa State      0
# 2314      North Carolina A&T      0
# 2315            Oregon State      0
# 2316  Middle Tennessee State      0
#
# [2317 rows x 7 columns]
